# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
bike_infra = "Bike_Network.csv"
bike_infra_df = pd.read_csv(bike_infra)
bike_infra_df.head()
# Out:
#    OBJECTID  SEG_ID    STREETNAME  ST_CODE ONEWAY  CLASS            TYPE  \
# 0         1  100002  BARTRAM  AVE    16120      B      2    Conventional
# 1         2  100003  BARTRAM  AVE    16120      B      2    Conventional
# 2         3  100004  BARTRAM  AVE    16120      B      2    Conventional
# 3         4  100040   ISLAND  AVE    45120     FT      2  Paint Buffered
# 4         5  100045  BARTRAM  AVE    16120      B      2    Conventional
#
#    Shape__Length
# 0    1116.637358
# 1     371.888030
# 2      48.720227
# 3     191.424196
# 4     410.264295

# %%
acc_data = "accident_data_philly.csv"
acc_data_df = pd.read_csv(acc_data)
acc_data_df.head()
# Out:
#      DATE        Time               STREET NAME  VEHICLES  TOTAL PEOPLE  \
# 0  11-Jan   3:36 a.m.  BENSON ST & FRANKFORD AV         2             3
# 1  11-Jan  21:00 p.m.           CONSHOHOCKEN AV         1             2
# 2  11-Jan  17:45 p.m.               WOODLAND AV         1             2
# 3  11-Jan   3:10 a.m.               GLENWOOD AV         1             2
# 4  11-Feb  16:37 p.m.                N FRONT ST         1             2
#
#    PEDESTRIANS  BICYCLISTS  INJURIES  MAJOR INJURIES  FATALITIES
# 0            1           0         0               0            1
# 1            1           0         1               1            0
# 2            1           0         0               0            1
# 3            1           0         1               1            0
# 4            1           0         0               0            1

# %%
# Create a filtered dataframe from specific columns of the bike infrastrucuture dataframe
# with values street names, street code, and type of infrastructure 

bike_infra_cols = bike_infra_df[["OBJECTID","STREETNAME", "TYPE"]].copy()
bike_infra_cols = bike_infra_cols.rename(columns={"TYPE": "Lane_Type", 
                                                 "STREETNAME": "Street_Name_lane"})
bike_infra_cols.head()
# Out:
#    OBJECTID Street_Name_lane       Lane_Type
# 0         1     BARTRAM  AVE    Conventional
# 1         2     BARTRAM  AVE    Conventional
# 2         3     BARTRAM  AVE    Conventional
# 3         4      ISLAND  AVE  Paint Buffered
# 4         5     BARTRAM  AVE    Conventional

# %%
# Create a filtered dataframe from specific columns of the bike accident dataframe
# with values street names, street code, and type of infrastructure 
acc_data_cols = acc_data_df[["STREET NAME", "BICYCLISTS", "INJURIES", "MAJOR INJURIES"]].copy()
acc_data_cols = acc_data_cols.rename(columns={"STREET NAME": "STREET_NAME", 
                                                 "MAJOR INJURIES": "MAJOR_INJURIES"})
acc_data_cols.head()
# Out:
#                 STREET_NAME  BICYCLISTS  INJURIES  MAJOR_INJURIES
# 0  BENSON ST & FRANKFORD AV           0         0               0
# 1           CONSHOHOCKEN AV           0         1               1
# 2               WOODLAND AV           0         0               0
# 3               GLENWOOD AV           0         1               1
# 4                N FRONT ST           0         0               0

# %%
connection_string = "postgres:postgres@localhost:5432/bike_acc_and_infra_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_1976\4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['infrastructure', 'accidents']

# %%
#make sure there are no null values in data 
#make sure columns names
#match data types as well

# %%
bike_infra_cols.to_sql(name='infrastructure', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
#     955         template=executemany_values,
# ...
